# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from scipy.sparse import csr_matrix
from IPython.display import display
from sklearn.cluster import KMeans

# %%
# Import the Movies dataset
movies = pd.read_csv('movies.csv')
movies.head()
# Out:
#    movieid                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Import the ratings dataset
ratings = pd.read_csv('ratings.csv')
ratings.head()
# Out:
#    userid  movieid  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
# Import the users dataset
users = pd.read_csv('users.csv')
users.head()
# Out:
#    userid gender  age  occupation zip-code
# 0       1      F    1          10    48067
# 1       2      M   56          16    70072
# 2       3      M   25          15    55117
# 3       4      M   45           7    02460
# 4       5      M   25          20    55455

# %%
#Separate men from women
female = users[users['gender'] == "F"]
print(female.head())
male = users[users['gender'] == "M"]
print(male.head())
# Out:
#     userid gender  age  occupation zip-code
# 0        1      F    1          10    48067
# 5        6      F   50           9    55117
# 9       10      F   35           1    95370
# 10      11      F   25           1    04093
# 15      16      F   35           0    20670
#    userid gender  age  occupation zip-code
# 1       2      M   56          16    70072
# 2       3      M   25          15    55117
# 3       4      M   45           7    02460
# 4       5      M   25          20    55455
# 6       7      M   35           1    06810

# %%
#All men rate scores and all women rate scores
f = female['userid']
m = male['userid']
a = []
b = []
for i in f:
    a.append(i)
aa = a[1:]
rat_female = ratings.loc[ratings['userid'] == 1]
for j in aa:
    rat_female = rat_female.append(ratings.loc[ratings['userid'] == j])
print("female's rate scores:")
print(rat_female)
for x in m:
    b.append(x)
bb = b[1:]
rat_male = ratings.loc[ratings['userid'] == 2]
for y in bb:
    rat_male = rat_male.append(ratings.loc[ratings['userid'] == y])
print("male's rate scores:")
print(rat_male)
# Out:
# female's rate scores:
#        userid  movieid  rating   timestamp
# 0           1       31     2.5  1260759144
# 1           1     1029     3.0  1260759179
# 2           1     1061     3.0  1260759182
# 3           1     1129     2.0  1260759185
# 4           1     1172     4.0  1260759205
# ...       ...      ...     ...         ...
# 99816     668     3000     3.0   993613196
# 99817     668     3039     3.0   993613196
# 99818     668     3213     3.0   993613359
# 99819     668     4012     3.0   993613196
# 99820     668     6425     1.0   993613478
#
# [27508 rows x 4 columns]
# male's rate scores:
#         userid  movieid  rating   timestamp
# 20           2       10     4.0   835355493
# 21           2       17     5.0   835355681
# 22           2       39     5.0   835355604
# 23           2       47     4.0   835355552
# 24           2       50     4.0   835355586
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [72496 rows x 4 columns]

# %%
ratings_title = pd.merge(ratings, movies[['movieid', 'title']], on='movieid' )
user_movie_ratings = pd.pivot_table(ratings_title, index='userid', columns= 'title', values='rating')

print('dataset dimensions: ', user_movie_ratings.shape, '\n\nSubset example:')
user_movie_ratings.iloc[:6, :10]
# Out:
# dataset dimensions:  (671, 9064)
#
# Subset example:
# title   "Great Performances" Cats (1998)  $9.99 (2008)  \
# userid
# 1                                    NaN           NaN
# 2                                    NaN           NaN
# 3                                    NaN           NaN
# 4                                    NaN           NaN
# 5                                    NaN           NaN
# 6                                    NaN           NaN
#
# title   'Hellboy': The Seeds of Creation (2004)  \
# userid
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
#
# title   'Neath the Arizona Skies (1934)  'Round Midnight (1986)  \
# userid
# 1                                   NaN                     NaN
# 2                                   NaN                     NaN
# 3                                   NaN                     NaN
# 4                                   NaN                     NaN
# 5                                   NaN                     NaN
# 6                                   NaN                     NaN
#
# title   'Salem's Lot (2004)  'Til There Was You (1997)  'burbs, The (1989)  \
# userid
# 1                       NaN                        NaN                 NaN
# 2                       NaN                        NaN                 NaN
# 3                       NaN                        NaN                 NaN
# 4                       NaN                        NaN                 NaN
# 5                       NaN                        NaN                 NaN
# 6                       NaN                        NaN                 4.0
#
# title   'night Mother (1986)  (500) Days of Summer (2009)
# userid
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
# 5                        NaN                          NaN
# 6                        NaN                          NaN

# %%
user_movie_ratings_f = user_movie_ratings.loc[a, :]
user_movie_ratings_f
# Out:
# title   "Great Performances" Cats (1998)  $9.99 (2008)  \
# userid
# 1                                    NaN           NaN
# 6                                    NaN           NaN
# 10                                   NaN           NaN
# 11                                   NaN           NaN
# 16                                   NaN           NaN
# ...                                  ...           ...
# 6035                                 NaN           NaN
# 6036                                 NaN           NaN
# 6037                                 NaN           NaN
# 6038                                 NaN           NaN
# 6039                                 NaN           NaN
#
# title   'Hellboy': The Seeds of Creation (2004)  \
# userid
# 1                                           NaN
# 6                                           NaN
# 10                                          NaN
# 11                                          NaN
# 16                                          NaN
# ...                                         ...
# 6035                                        NaN
# 6036                                        NaN
# 6037                                        NaN
# 6038                                        NaN
# 6039                                        NaN
#
# title   'Neath the Arizona Skies (1934)  'Round Midnight (1986)  \
# userid
# 1                                   NaN                     NaN
# 6                                   NaN                     NaN
# 10                                  NaN                     NaN
# 11                                  NaN                     NaN
# 16                                  NaN                     NaN
# ...                                 ...                     ...
# 6035                                NaN                     NaN
# 6036                                NaN                     NaN
# 6037                                NaN                     NaN
# 6038                                NaN                     NaN
# 6039                                NaN                     NaN
#
# title   'Salem's Lot (2004)  'Til There Was You (1997)  'burbs, The (1989)  \
# userid
# 1                       NaN                        NaN                 NaN
# 6                       NaN                        NaN                 4.0
# 10                      NaN                        NaN                 NaN
# 11                      NaN                        NaN                 NaN
# 16                      NaN                        NaN                 NaN
# ...                     ...                        ...                 ...
# 6035                    NaN                        NaN                 NaN
# 6036                    NaN                        NaN                 NaN
# 6037                    NaN                        NaN                 NaN
# 6038                    NaN                        NaN                 NaN
# 6039                    NaN                        NaN                 NaN
#
# title   'night Mother (1986)  (500) Days of Summer (2009)  ...  Zulu (1964)  \
# userid                                                     ...
# 1                        NaN                          NaN  ...          NaN
# 6                        NaN                          NaN  ...          NaN
# 10                       NaN                          NaN  ...          NaN
# 11                       NaN                          NaN  ...          NaN
# 16                       NaN                          NaN  ...          NaN
# ...                      ...                          ...  ...          ...
# 6035                     NaN                          NaN  ...          NaN
# 6036                     NaN                          NaN  ...          NaN
# 6037                     NaN                          NaN  ...          NaN
# 6038                     NaN                          NaN  ...          NaN
# 6039                     NaN                          NaN  ...          NaN
#
# title   Zulu (2013)  [REC] (2007)  eXistenZ (1999)  \
# userid
# 1               NaN           NaN              NaN
# 6               NaN           NaN              NaN
# 10              NaN           NaN              NaN
# 11              NaN           NaN              NaN
# 16              NaN           NaN              NaN
# ...             ...           ...              ...
# 6035            NaN           NaN              NaN
# 6036            NaN           NaN              NaN
# 6037            NaN           NaN              NaN
# 6038            NaN           NaN              NaN
# 6039            NaN           NaN              NaN
#
# title   loudQUIETloud: A Film About the Pixies (2006)  xXx (2002)  \
# userid
# 1                                                 NaN         NaN
# 6                                                 NaN         NaN
# 10                                                NaN         NaN
# 11                                                NaN         NaN
# 16                                                NaN         NaN
# ...                                               ...         ...
# 6035                                              NaN         NaN
# 6036                                              NaN         NaN
# 6037                                              NaN         NaN
# 6038                                              NaN         NaN
# 6039                                              NaN         NaN
#
# title   xXx: State of the Union (2005)  ¡Three Amigos! (1986)  \
# userid
# 1                                  NaN                    NaN
# 6                                  NaN                    NaN
# 10                                 NaN                    NaN
# 11                                 NaN                    NaN
# 16                                 NaN                    NaN
# ...                                ...                    ...
# 6035                               NaN                    NaN
# 6036                               NaN                    NaN
# 6037                               NaN                    NaN
# 6038                               NaN                    NaN
# 6039                               NaN                    NaN
#
# title   À nous la liberté (Freedom for Us) (1931)  İtirazım Var (2014)
# userid
# 1                                             NaN                  NaN
# 6                                             NaN                  NaN
# 10                                            NaN                  NaN
# 11                                            NaN                  NaN
# 16                                            NaN                  NaN
# ...                                           ...                  ...
# 6035                                          NaN                  NaN
# 6036                                          NaN                  NaN
# 6037                                          NaN                  NaN
# 6038                                          NaN                  NaN
# 6039                                          NaN                  NaN
#
# [1709 rows x 9064 columns]

# %%
user_movie_ratings_m = user_movie_ratings.loc[b, :]
user_movie_ratings_m
# Out:
# title   "Great Performances" Cats (1998)  $9.99 (2008)  \
# userid
# 2                                    NaN           NaN
# 3                                    NaN           NaN
# 4                                    NaN           NaN
# 5                                    NaN           NaN
# 7                                    NaN           NaN
# ...                                  ...           ...
# 6030                                 NaN           NaN
# 6032                                 NaN           NaN
# 6033                                 NaN           NaN
# 6034                                 NaN           NaN
# 6040                                 NaN           NaN
#
# title   'Hellboy': The Seeds of Creation (2004)  \
# userid
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 7                                           NaN
# ...                                         ...
# 6030                                        NaN
# 6032                                        NaN
# 6033                                        NaN
# 6034                                        NaN
# 6040                                        NaN
#
# title   'Neath the Arizona Skies (1934)  'Round Midnight (1986)  \
# userid
# 2                                   NaN                     NaN
# 3                                   NaN                     NaN
# 4                                   NaN                     NaN
# 5                                   NaN                     NaN
# 7                                   NaN                     NaN
# ...                                 ...                     ...
# 6030                                NaN                     NaN
# 6032                                NaN                     NaN
# 6033                                NaN                     NaN
# 6034                                NaN                     NaN
# 6040                                NaN                     NaN
#
# title   'Salem's Lot (2004)  'Til There Was You (1997)  'burbs, The (1989)  \
# userid
# 2                       NaN                        NaN                 NaN
# 3                       NaN                        NaN                 NaN
# 4                       NaN                        NaN                 NaN
# 5                       NaN                        NaN                 NaN
# 7                       NaN                        NaN                 NaN
# ...                     ...                        ...                 ...
# 6030                    NaN                        NaN                 NaN
# 6032                    NaN                        NaN                 NaN
# 6033                    NaN                        NaN                 NaN
# 6034                    NaN                        NaN                 NaN
# 6040                    NaN                        NaN                 NaN
#
# title   'night Mother (1986)  (500) Days of Summer (2009)  ...  Zulu (1964)  \
# userid                                                     ...
# 2                        NaN                          NaN  ...          NaN
# 3                        NaN                          NaN  ...          NaN
# 4                        NaN                          NaN  ...          NaN
# 5                        NaN                          NaN  ...          NaN
# 7                        NaN                          NaN  ...          NaN
# ...                      ...                          ...  ...          ...
# 6030                     NaN                          NaN  ...          NaN
# 6032                     NaN                          NaN  ...          NaN
# 6033                     NaN                          NaN  ...          NaN
# 6034                     NaN                          NaN  ...          NaN
# 6040                     NaN                          NaN  ...          NaN
#
# title   Zulu (2013)  [REC] (2007)  eXistenZ (1999)  \
# userid
# 2               NaN           NaN              NaN
# 3               NaN           NaN              NaN
# 4               NaN           NaN              NaN
# 5               NaN           NaN              NaN
# 7               NaN           NaN              NaN
# ...             ...           ...              ...
# 6030            NaN           NaN              NaN
# 6032            NaN           NaN              NaN
# 6033            NaN           NaN              NaN
# 6034            NaN           NaN              NaN
# 6040            NaN           NaN              NaN
#
# title   loudQUIETloud: A Film About the Pixies (2006)  xXx (2002)  \
# userid
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 7                                                 NaN         NaN
# ...                                               ...         ...
# 6030                                              NaN         NaN
# 6032                                              NaN         NaN
# 6033                                              NaN         NaN
# 6034                                              NaN         NaN
# 6040                                              NaN         NaN
#
# title   xXx: State of the Union (2005)  ¡Three Amigos! (1986)  \
# userid
# 2                                  NaN                    NaN
# 3                                  NaN                    NaN
# 4                                  NaN                    NaN
# 5                                  NaN                    NaN
# 7                                  NaN                    NaN
# ...                                ...                    ...
# 6030                               NaN                    NaN
# 6032                               NaN                    NaN
# 6033                               NaN                    NaN
# 6034                               NaN                    NaN
# 6040                               NaN                    NaN
#
# title   À nous la liberté (Freedom for Us) (1931)  İtirazım Var (2014)
# userid
# 2                                             NaN                  NaN
# 3                                             NaN                  NaN
# 4                                             NaN                  NaN
# 5                                             NaN                  NaN
# 7                                             NaN                  NaN
# ...                                           ...                  ...
# 6030                                          NaN                  NaN
# 6032                                          NaN                  NaN
# 6033                                          NaN                  NaN
# 6034                                          NaN                  NaN
# 6040                                          NaN                  NaN
#
# [4331 rows x 9064 columns]

# %%
#It can be seen from the table above that many users have not seen many movies, and there are fewer female users and movies they have seen. Therefore, the top 800 films that female users have seen the most are selected for clustering

def get_most_rated_movies(user_movie_ratings, max_number_of_movies):
    # 1- Count
    user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)
    # 2- sort
    user_movie_ratings_sorted = user_movie_ratings.sort_values(len(user_movie_ratings) - 1, axis=1, ascending=False)
    user_movie_ratings_sorted = user_movie_ratings_sorted.drop(user_movie_ratings_sorted.tail(1).index)
    # 3- slice
    most_rated_movies = user_movie_ratings_sorted.iloc[:, :max_number_of_movies]
    return most_rated_movies

user_movie_ratings_f =  pd.pivot_table(ratings_title, index='userid', columns= 'title', values='rating')
most_rated_movies_800_f = helper.get_most_rated_movies(user_movie_ratings, 800)
most_rated_movies_800_f
# Out:
# title  Forrest Gump (1994)  Pulp Fiction (1994)  \
# 0                      NaN                  NaN
# 1                      3.0                  4.0
# 2                      5.0                  4.5
# 3                      5.0                  5.0
# 4                      4.0                  NaN
# ..                     ...                  ...
# 666                    4.0                  5.0
# 667                    NaN                  5.0
# 668                    NaN                  NaN
# 669                    NaN                  NaN
# 670                    5.0                  4.0
#
# title  Shawshank Redemption, The (1994)  Silence of the Lambs, The (1991)  \
# 0                                   NaN                               NaN
# 1                                   NaN                               3.0
# 2                                   5.0                               3.0
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
# ..                                  ...                               ...
# 666                                 NaN                               NaN
# 667                                 4.0                               5.0
# 668                                 NaN                               NaN
# 669                                 5.0                               5.0
# 670                                 5.0                               NaN
#
# title  Star Wars: Episode IV - A New Hope (1977)  Jurassic Park (1993)  \
# 0                                            NaN                   NaN
# 1                                            NaN                   4.0
# 2                                            NaN                   NaN
# 3                                            5.0                   5.0
# 4                                            NaN                   NaN
# ..                                           ...                   ...
# 666                                          NaN                   4.0
# 667                                          NaN                   NaN
# 668                                          5.0                   3.0
# 669                                          NaN                   NaN
# 670                                          5.0                   NaN
#
# title  Matrix, The (1999)  Toy Story (1995)  Schindler's List (1993)  \
# 0                     NaN               NaN                      NaN
# 1                     NaN               NaN                      4.0
# 2                     NaN               NaN                      3.0
# 3                     NaN               NaN                      NaN
# 4                     NaN               NaN                      NaN
# ..                    ...               ...                      ...
# 666                   NaN               NaN                      NaN
# 667                   NaN               NaN                      NaN
# 668                   NaN               NaN                      NaN
# 669                   4.0               4.0                      5.0
# 670                   4.5               5.0                      NaN
#
# title  Terminator 2: Judgment Day (1991)  ...  Bob Roberts (1992)  \
# 0                                    NaN  ...                 NaN
# 1                                    5.0  ...                 NaN
# 2                                    NaN  ...                 NaN
# 3                                    5.0  ...                 NaN
# 4                                    NaN  ...                 NaN
# ..                                   ...  ...                 ...
# 666                                  NaN  ...                 NaN
# 667                                  NaN  ...                 NaN
# 668                                  NaN  ...                 NaN
# 669                                  NaN  ...                 NaN
# 670                                  5.0  ...                 NaN
#
# title  Falling Down (1993)  Simple Plan, A (1998)  Color Purple, The (1985)  \
# 0                      NaN                    NaN                       NaN
# 1                      NaN                    NaN                       NaN
# 2                      NaN                    NaN                       NaN
# 3                      NaN                    NaN                       NaN
# 4                      NaN                    NaN                       NaN
# ..                     ...                    ...                       ...
# 666                    NaN                    NaN                       NaN
# 667                    NaN                    NaN                       NaN
# 668                    NaN                    NaN                       NaN
# 669                    NaN                    NaN                       NaN
# 670                    NaN                    NaN                       NaN
#
# title  Free Willy (1993)  Bulworth (1998)  Secret Garden, The (1993)  \
# 0                    NaN              NaN                        NaN
# 1                    NaN              NaN                        NaN
# 2                    NaN              NaN                        NaN
# 3                    NaN              NaN                        NaN
# 4                    NaN              NaN                        NaN
# ..                   ...              ...                        ...
# 666                  NaN              NaN                        NaN
# 667                  NaN              NaN                        NaN
# 668                  NaN              NaN                        NaN
# 669                  NaN              NaN                        NaN
# 670                  NaN              NaN                        NaN
#
# title  Die Another Day (2002)  Taken (2008)  Grapes of Wrath, The (1940)
# 0                         NaN           NaN                          NaN
# 1                         NaN           NaN                          NaN
# 2                         NaN           NaN                          NaN
# 3                         NaN           NaN                          NaN
# 4                         NaN           NaN                          NaN
# ..                        ...           ...                          ...
# 666                       NaN           NaN                          NaN
# 667                       NaN           NaN                          NaN
# 668                       NaN           NaN                          NaN
# 669                       NaN           NaN                          NaN
# 670                       NaN           NaN                          NaN
#
# [671 rows x 800 columns]

# %%
#In order to cluster the data with blank values, it is transformed into sparse CSR matrix
sparse_ratings_f = csr_matrix(pd.SparseDataFrame(most_rated_movies_800_f).to_coo())
sparse_ratings_f
# Out:
# <ipython-input-29-68369c1e4ff0>:2: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   sparse_ratings_f = csr_matrix(pd.SparseDataFrame(most_rated_movies_800_f).to_coo())
# c:\users\dell\pycharmprojects\pythonproject\venv\lib\site-packages\pandas\core\frame.py:3471: FutureWarning: SparseSeries is deprecated and will be removed in a future version.
# Use a Series with sparse values instead.
#
#     >>> series = pd.Series(pd.SparseArray(...))
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return klass(values, index=self.index, name=items, fastpath=True)
# <671x800 sparse matrix of type '<class 'numpy.float64'>'
# 	with 56784 stored elements in Compressed Sparse Row format>

# %%
#Because many users have not seen many movies, the score is blank, so it is difficult to judge the K value of clustering, so it is convenient to select k value by filling with 0
from scipy.spatial.distance import cdist
most_rated_movies_800_f_0 =  most_rated_movies_800_f.fillna(0)

# %%
#female  k  
zscore_data_f = (most_rated_movies_800_f_0-most_rated_movies_800_f_0.mean())/most_rated_movies_800_f_0.std()
K = range(1, 50)
meandistortions_f = []
for k in K:
    kmeans_s_f = KMeans(n_clusters=k)
    kmeans_s_f.fit(most_rated_movies_800_f_0)
    meandistortions_f.append(sum(np.min(cdist(most_rated_movies_800_f_0, kmeans_s_f.cluster_centers_, 'euclidean'), axis=1))/most_rated_movies_800_f_0.shape[0])
    #cdist: Compute the distance 'Euclidean' of all vector pairs between two matrix rows
plt.plot(K, meandistortions_f, 'bx-')
plt.xlabel('k')
plt.ylabel('Average Dispersion')
plt.title('Selecting k with the Elbow Method')
plt.show()

# %%
#Based on the diagram and the actual situation, 10 is more appropriate
kmeans_f = KMeans(n_clusters=10, algorithm='full').fit_predict(sparse_ratings_f)
max_users = 50
max_movies = 50

def draw_movie_clusters(clustered, max_users, max_movies):
    c = 1
    for cluster_id in clustered.group.unique():
        # To improve visibility, we're showing at most max_users users and max_movies movies per cluster.
        # You can change these values to see more users & movies per cluster
        d = clustered[clustered.group == cluster_id].drop(['index', 'group'], axis=1)
        n_users_in_cluster = d.shape[0]

        d = sort_by_rating_density(d, max_movies, max_users)

        d = d.reindex(d.mean().sort_values(ascending=False).index, axis=1)
        d = d.reindex(d.count(axis=1).sort_values(ascending=False).index)
        d = d.iloc[:max_users, :max_movies]
        n_users_in_plot = d.shape[0]

        # We're only selecting to show clusters that have more than 9 users, otherwise, they're less interesting
        if len(d) > 9:
            print('cluster # {}'.format(cluster_id))
            print('# of users in cluster: {}.'.format(n_users_in_cluster),
                  '# of users in plot: {}'.format(n_users_in_plot))
            fig = plt.figure(figsize=(15, 4))
            ax = plt.gca()

            ax.invert_yaxis()
            ax.xaxis.tick_top()
            labels = d.columns.str[:40]

            ax.set_yticks(np.arange(d.shape[0]), minor=False)
            ax.set_xticks(np.arange(d.shape[1]), minor=False)

            ax.set_xticklabels(labels, minor=False)

            ax.get_yaxis().set_visible(False)

            # Heatmap
            heatmap = plt.imshow(d, vmin=0, vmax=5, aspect='auto')

            ax.set_xlabel('movies')
            ax.set_ylabel('User id')

            divider = make_axes_locatable(ax)
            cax = divider.append_axes("right", size="5%", pad=0.05)

            # Color bar
            cbar = fig.colorbar(heatmap, ticks=[5, 4, 3, 2, 1, 0], cax=cax)
            cbar.ax.set_yticklabels(['5 stars', '4 stars', '3 stars', '2 stars', '1 stars', '0 stars'])

            plt.setp(ax.get_xticklabels(), rotation=90, fontsize=9)
            plt.tick_params(axis='both', which='both', bottom='off', top='off', left='off', labelbottom='off',
                            labelleft='off')
            # print('cluster # {} \n(Showing at most {} users and {} movies)'.format(cluster_id, max_users, max_movies))

            plt.show()

clustered_f = pd.concat([most_rated_movies_800_f.reset_index(), pd.DataFrame({'group':kmeans_f})], axis=1)
draw_movie_clusters(clustered_f, max_users, max_movies)
# Out:
# cluster # 9
# # of users in cluster: 289. # of users in plot: 50
# cluster # 0
# # of users in cluster: 82. # of users in plot: 50
# cluster # 1
# # of users in cluster: 37. # of users in plot: 37
# cluster # 6
# # of users in cluster: 113. # of users in plot: 50
# cluster # 2
# # of users in cluster: 16. # of users in plot: 16
# cluster # 4
# # of users in cluster: 36. # of users in plot: 36
# cluster # 5
# # of users in cluster: 38. # of users in plot: 38
# cluster # 3
# # of users in cluster: 39. # of users in plot: 39
# cluster # 7
# # of users in cluster: 12. # of users in plot: 12

# %%
#The following movie recommendation prediction, first select a group and users
cluster_f_number = 7

# View the dataset area with the highest number of values

def sort_by_rating_density(user_movie_ratings, n_movies, n_users):
    most_rated_movies = get_most_rated_movies(user_movie_ratings, n_movies)
    most_rated_movies = get_users_who_rate_the_most(most_rated_movies, n_users)
    return most_rated_movies

def draw_movies_heatmap(most_rated_movies_users_selection, axis_labels=True):
    # Reverse to match the order of the printed dataframe
    # most_rated_movies_users_selection = most_rated_movies_users_selection.iloc[::-1]

    fig = plt.figure(figsize=(15, 4))
    ax = plt.gca()

    # Draw heatmap
    heatmap = ax.imshow(most_rated_movies_users_selection, interpolation='nearest', vmin=0, vmax=5, aspect='auto')

    if axis_labels:
        ax.set_yticks(np.arange(most_rated_movies_users_selection.shape[0]), minor=False)
        ax.set_xticks(np.arange(most_rated_movies_users_selection.shape[1]), minor=False)
        ax.invert_yaxis()
        ax.xaxis.tick_top()
        labels = most_rated_movies_users_selection.columns.str[:40]
        ax.set_xticklabels(labels, minor=False)
        ax.set_yticklabels(most_rated_movies_users_selection.index, minor=False)
        plt.setp(ax.get_xticklabels(), rotation=90)
    else:
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    ax.grid(False)
    ax.set_ylabel('User id')

    # Separate heatmap from color bar
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)

    # Color bar
    cbar = fig.colorbar(heatmap, ticks=[5, 4, 3, 2, 1, 0], cax=cax)
    cbar.ax.set_yticklabels(['5 stars', '4 stars', '3 stars', '2 stars', '1 stars', '0 stars'])

    plt.show()
    
    
n_users = 50
n_movies = 250
cluster_f = clustered_f[clustered_f.group == cluster_f_number].drop(['index', 'group'], axis=1)

cluster_f = sort_by_rating_density(cluster_f, n_movies, n_users)
draw_movies_heatmap(cluster_f, axis_labels=False)

# %%
#View the actual rating table
cluster_f.fillna('').head()
# Out:
#    Forrest Gump (1994)  Back to the Future (1985)  Princess Bride, The (1987)  \
# 9                  3.0                        3.0                         4.0
# 0                  3.0                        4.0                         4.0
# 8                  5.0                        4.0                         5.0
# 6                  5.0                        4.5                         3.0
# 1                  3.5                        4.0                         4.5
#
#    E.T. the Extra-Terrestrial (1982)  Honey, I Shrunk the Kids (1989)  \
# 9                                4.0                              4.0
# 0                                4.0                              2.0
# 8                                5.0                              4.0
# 6                                4.0                              3.5
# 1                                3.0                              3.0
#
#    Indiana Jones and the Last Crusade (1989)  \
# 9                                        4.0
# 0                                        3.0
# 8                                        5.0
# 6                                        4.5
# 1                                        4.0
#
#    Star Wars: Episode I - The Phantom Menace (1999)  \
# 9                                               2.0
# 0                                               3.0
# 8                                               5.0
# 6                                               2.5
# 1                                               3.5
#
#    Dances with Wolves (1990)  Ferris Bueller's Day Off (1986)  \
# 9                        2.0                              4.0
# 0                        5.0                              4.0
# 8                        2.0                              5.0
# 6                        5.0                              3.5
# 1                        4.0                              4.5
#
#    Star Wars: Episode VI - Return of the Jedi (1983)  ...  Casablanca (1942)  \
# 9                                                3.0  ...                  4
# 0                                                4.0  ...                  5
# 8                                                5.0  ...                  3
# 6                                                3.5  ...                  3
# 1                                                4.0  ...
#
#    Clear and Present Danger (1994)  Jerry Maguire (1996)  Office Space (1999)  \
# 9                                4
# 0                                                                           4
# 8                                                      5
# 6                                3                     5
# 1                                3                     2                  4.5
#
#    Apocalypse Now (1979)  Austin Powers: International Man of Mystery (1997)  \
# 9                      4                                                  2
# 0                      5                                                  2
# 8                                                                         4
# 6
# 1                    4.5
#
#    Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  \
# 9                                          4
# 0                                          4
# 8
# 6
# 1
#
#    O Brother, Where Art Thou? (2000)  American President, The (1995)  \
# 9                                                                  3
# 0
# 8                                                                  5
# 6                                4.5                               5
# 1                                4.5
#
#   Crimson Tide (1995)
# 9                   4
# 0                   4
# 8
# 6                   3
# 1
#
# [5 rows x 250 columns]

# %%
#Choose a movie with a blank value as an example, choose movie: Casablanca (1942)
movie_name = "Casablanca (1942)"

cluster_f[movie_name].mean()
# Out:
# 4.0

# %%
#Obviously, group 7 has a high score for this movie, so it can recommend this movie to other users who have not seen it
#At the same time, you can view all the average scores and sort them. You can start from the highest to recommend them to users who haven't seen them
qwqwq = cluster_f.mean()
qwqwq.sort_values(ascending = False)
# Out:
# Schindler's List (1993)                                  4.555556
# It's a Wonderful Life (1946)                             4.500000
# Monty Python and the Holy Grail (1975)                   4.500000
# American Beauty (1999)                                   4.500000
# Star Wars: Episode V - The Empire Strikes Back (1980)    4.458333
#                                                            ...
# Outbreak (1995)                                          2.555556
# Legends of the Fall (1994)                               2.500000
# Hook (1991)                                              2.250000
# Wild Wild West (1999)                                    2.214286
# Congo (1995)                                             1.625000
# Length: 250, dtype: float64
